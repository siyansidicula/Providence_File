# %% [markdown]
# <a href="https://colab.research.google.com/github/siyansidicula/Providence_File/blob/main/1_OurOwnData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Training------------------------------------
#1.load the data(our own data)
x=[[2,3],[90,78,],[5,8],[73,43],[37,62]]
y=["Cat","Dog","Tiger","Dog","Cat"]
#2.load the model
from sklearn.linear_model import Perceptron
a=Perceptron()
#3.Fit data into the model
a.fit(x,y)
#Testing-------------------------------------predict
op=a.predict([[84,5]])
print(op)
